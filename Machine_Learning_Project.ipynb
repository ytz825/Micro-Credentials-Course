# %% [markdown]
# <a href="https://colab.research.google.com/github/ytz825/Micro-Credentials-Course/blob/main/Machine_Learning_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#loading data
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/cuny_lagcc_micro_credential_data_analytics/main/Track%20A/Unit%204%20-%20Machine%20Learning%20and%20Modeling%20Techniques/Dataset/diabetic_data.csv')
df
# Out:
#         encounter_id  patient_nbr  ... diabetesMed readmitted
# 0            2278392      8222157  ...          No         NO
# 1             149190     55629189  ...         Yes        >30
# 2              64410     86047875  ...         Yes         NO
# 3             500364     82442376  ...         Yes         NO
# 4              16680     42519267  ...         Yes         NO
# ...              ...          ...  ...         ...        ...
# 101761     443847548    100162476  ...         Yes        >30
# 101762     443847782     74694222  ...         Yes         NO
# 101763     443854148     41088789  ...         Yes         NO
# 101764     443857166     31693671  ...         Yes         NO
# 101765     443867222    175429310  ...          No         NO
#
# [101766 rows x 50 columns]

# %%
#dropping unnecessary columns
df.drop(['encounter_id','weight','admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'payer_code', 'medical_specialty', 'patient_nbr', 'diag_1', 'diag_2', 'diag_3','metformin','repaglinide','nateglinide','chlorpropamide','glimepiride','acetohexamide','glipizide','glyburide','tolbutamide','pioglitazone','rosiglitazone','acarbose','miglitol','troglitazone','tolazamide','examide','citoglipton','insulin','glyburide-metformin','glipizide-metformin','glimepiride-pioglitazone','metformin-rosiglitazone','metformin-pioglitazone','A1Cresult','max_glu_serum'], inplace=True, axis=1)
df
# Out:
#                    race  gender      age  ...  change  diabetesMed  readmitted
# 0             Caucasian  Female   [0-10)  ...      No           No          NO
# 1             Caucasian  Female  [10-20)  ...      Ch          Yes         >30
# 2       AfricanAmerican  Female  [20-30)  ...      No          Yes          NO
# 3             Caucasian    Male  [30-40)  ...      Ch          Yes          NO
# 4             Caucasian    Male  [40-50)  ...      Ch          Yes          NO
# ...                 ...     ...      ...  ...     ...          ...         ...
# 101761  AfricanAmerican    Male  [70-80)  ...      Ch          Yes         >30
# 101762  AfricanAmerican  Female  [80-90)  ...      No          Yes          NO
# 101763        Caucasian    Male  [70-80)  ...      Ch          Yes          NO
# 101764        Caucasian  Female  [80-90)  ...      Ch          Yes          NO
# 101765        Caucasian    Male  [70-80)  ...      No           No          NO
#
# [101766 rows x 14 columns]

# %%
#creating a dictionary for race
race_dict = {'?':0, 'AfricanAmerican':1, 'Asian':2, 'Caucasian':3, 'Hispanic':4, 'Other':5}
race_dict
# Out:
# {'?': 0,
#  'AfricanAmerican': 1,
#  'Asian': 2,
#  'Caucasian': 3,
#  'Hispanic': 4,
#  'Other': 5}

# %%
#replacing race with dictionary values
df.race = [race_dict[item] for item in df.race] 
print(df)
# Out:
#         race  gender      age  ...  change  diabetesMed  readmitted
# 0          3  Female   [0-10)  ...      No           No          NO
# 1          3  Female  [10-20)  ...      Ch          Yes         >30
# 2          1  Female  [20-30)  ...      No          Yes          NO
# 3          3    Male  [30-40)  ...      Ch          Yes          NO
# 4          3    Male  [40-50)  ...      Ch          Yes          NO
# ...      ...     ...      ...  ...     ...          ...         ...
# 101761     1    Male  [70-80)  ...      Ch          Yes         >30
# 101762     1  Female  [80-90)  ...      No          Yes          NO
# 101763     3    Male  [70-80)  ...      Ch          Yes          NO
# 101764     3  Female  [80-90)  ...      Ch          Yes          NO
# 101765     3    Male  [70-80)  ...      No           No          NO
#
# [101766 rows x 14 columns]

# %%
#creating dictionaries for all non-float columns and replace them in the original data set
readmitted_dict = {'NO':0, '>30':1, '<30':2}
df.readmitted = [readmitted_dict[item] for item in df.readmitted]
change_dict = {'No':0, 'Ch':1}
df.change = [change_dict[item] for item in df.change] 
diabetesMed_dict = {'No':0, 'Yes':1}
df.diabetesMed = [diabetesMed_dict[item] for item in df.diabetesMed]
gender_dict = {'Female':0, 'Male':1, 'Unknown/Invalid':2}
df.gender = [gender_dict[item] for item in df.gender] 
age_dict = {'[0-10)':0, '[10-20)':1, '[20-30)':2, '[30-40)':3, '[40-50)':4, '[50-60)':5, '[60-70)':6, '[70-80)':7, '[80-90)':8, '[90-100)':9}
df.age = [age_dict[item] for item in df.age] 
df
# Out:
#         race  gender  age  ...  change  diabetesMed  readmitted
# 0          3       0    0  ...       0            0           0
# 1          3       0    1  ...       1            1           1
# 2          1       0    2  ...       0            1           0
# 3          3       1    3  ...       1            1           0
# 4          3       1    4  ...       1            1           0
# ...      ...     ...  ...  ...     ...          ...         ...
# 101761     1       1    7  ...       1            1           1
# 101762     1       0    8  ...       0            1           0
# 101763     3       1    7  ...       1            1           0
# 101764     3       0    8  ...       1            1           0
# 101765     3       1    7  ...       0            0           0
#
# [101766 rows x 14 columns]

# %%
#KNN
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df.drop('readmitted', axis=1))
StandardScaler(copy=True, with_mean=True, with_std=True)
scaled_features = scaler.transform(df.drop('readmitted',axis=1))
df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()
# Out:
#        race    gender       age  ...  number_diagnoses    change  diabetesMed
# 0  0.427557 -0.927397 -3.824600  ...         -3.321596 -0.926591    -1.829868
# 1  0.427557 -0.927397 -3.197277  ...          0.815784  1.079225     0.546488
# 2 -1.703706 -0.927397 -2.569954  ...         -0.735733 -0.926591     0.546488
# 3  0.427557  1.078031 -1.942632  ...         -0.218561  1.079225     0.546488
# 4  0.427557  1.078031 -1.315309  ...         -1.252906  1.079225     0.546488
#
# [5 rows x 13 columns]

# %%
#to see which race has the highest chance of getting hospitalized
sns.countplot(df['race'], label='Count')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#to see which age group has the highest chance of getting hospitalized
sns.countplot(df['age'], label='Count')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#same as above, but in a histogram
df['age'].hist(bins=20)

# %%
#to see which age group has the most number of diagnoses
plt.figure(figsize=(40,15))
sns.barplot(x='age',y='number_diagnoses',data=df,palette='deep')

# %%
#dropping the column we want to predict
x = df.drop(['readmitted'],axis=1)
x
# Out:
#         race  gender  age  ...  number_diagnoses  change  diabetesMed
# 0          3       0    0  ...                 1       0            0
# 1          3       0    1  ...                 9       1            1
# 2          1       0    2  ...                 6       0            1
# 3          3       1    3  ...                 7       1            1
# 4          3       1    4  ...                 5       1            1
# ...      ...     ...  ...  ...               ...     ...          ...
# 101761     1       1    7  ...                 9       1            1
# 101762     1       0    8  ...                 9       0            1
# 101763     3       1    7  ...                13       1            1
# 101764     3       0    8  ...                 9       1            1
# 101765     3       1    7  ...                 9       0            0
#
# [101766 rows x 13 columns]

# %%
#storing the dropped column
y = df['readmitted']

# %%
#random tree test
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 5)

# %%
x_train.shape
# Out:
# (81412, 13)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

randomforest_classifier = RandomForestClassifier(n_estimators = 100, criterion = 'entropy')
randomforest_classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
y_predict_train = randomforest_classifier.predict(x_train)
cm = confusion_matrix(y_train, y_predict_train)

# %%
sns.heatmap(cm, annot=True)

# %%
print(classification_report(y_train, y_predict_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     43895
#            1       1.00      1.00      1.00     28507
#            2       1.00      1.00      1.00      9010
#
#     accuracy                           1.00     81412
#    macro avg       1.00      1.00      1.00     81412
# weighted avg       1.00      1.00      1.00     81412

# %%
y_predict = randomforest_classifier.predict(x_test)
cm = confusion_matrix(y_test, y_predict)

# %%
sns.heatmap(cm, annot=True)

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      0.78      0.68     10969
#            1       0.43      0.35      0.39      7038
#            2       0.24      0.03      0.06      2347
#
#     accuracy                           0.55     20354
#    macro avg       0.43      0.39      0.37     20354
# weighted avg       0.50      0.55      0.51     20354

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors=319)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=319, p=2,
#                      weights='uniform')

# %%
y_pred = model.predict(x_test)

# %%
from sklearn import metrics
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5520782155841604
